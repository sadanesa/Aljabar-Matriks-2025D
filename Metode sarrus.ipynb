# %%
a = (int(input("Masukkan Matriks a11: ")))
b = (int(input("Masukkan Matriks a12: ")))
c = (int(input("Masukkan Matriks a13: ")))
d = (int(input("Masukkan Matriks a21: ")))
e = (int(input("Masukkan Matriks a22: ")))
f = (int(input("Masukkan Matriks a23: ")))
g = (int(input("Masukkan Matriks a31: ")))
h = (int(input("Masukkan Matriks a32: ")))
i = (int(input("Masukkan Matriks a33: ")))

aei = a*e*i
bfg = b*f*g
cdh = c*d*h
diagonal_utama = aei+bfg+cdh

ceg = c*e*g
afh = a*f*h
bdi = b*d*i
diagonal_sekunder = ceg+afh+bdi

determinan = diagonal_utama - diagonal_sekunder
print("Determinan = ", determinan)
# Out:
# Masukkan Matriks a11: 7
# Masukkan Matriks a12: 5
# Masukkan Matriks a13: 2
# Masukkan Matriks a21: 3
# Masukkan Matriks a22: 0
# Masukkan Matriks a23: 1
# Masukkan Matriks a31: 1
# Masukkan Matriks a32: 6
# Masukkan Matriks a33: 3
# Determinan =  -46
