# %%
A = [2,3,4]
B = [4,5,8]
Dotproduct = 0
for i in range (len(A)):
  value = A[i]*B[i]
  Dotproduct += value
print(Dotproduct)
# Out:
# 55

# %%
A = [9,3,4]
B = [4,5,8]
Dotproduct = 0
for i in range (len(A)):
  value = A[i]*B[i]
  Dotproduct += value
print(Dotproduct)
# Out:
# 83

# %%
import numpy as np

A = [4,5,6]
B = [7,4,6]

Dotproduct = np.dot(A,B)
print(Dotproduct)
# Out:
# 84
